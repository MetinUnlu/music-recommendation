# %%
# Reference:
# Create a binary feature matrix for the genres
# https://medium.com/@prateekgaurav/step-by-step-content-based-recommendation-system-823bbfd0541c

# %%
#Import all the required packages
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# Load the movies.csv file into a Pandas dataframe
music_df = pd.read_csv('../data/music_info.csv')

# %%
music_df.head(5)
# Out:
#              track_id             name           artist  \
# 0  TRIOREW128F424EAF0   Mr. Brightside      The Killers
# 1  TRRIVDJ128F429B0E8       Wonderwall            Oasis
# 2  TROUVHL128F426C441  Come as You Are          Nirvana
# 3  TRUEIND128F93038C4      Take Me Out  Franz Ferdinand
# 4  TRLNZBD128F935E4D8            Creep        Radiohead
#
#                                  spotify_preview_url              spotify_id  \
# 0  https://p.scdn.co/mp3-preview/4d26180e6961fd46...  09ZQ5TmUG8TSL56n0knqrj
# 1  https://p.scdn.co/mp3-preview/d012e536916c927b...  06UfBBDISthj1ZJAtX4xjj
# 2  https://p.scdn.co/mp3-preview/a1c11bb1cb231031...  0keNu0t0tqsWtExGM3nT1D
# 3  https://p.scdn.co/mp3-preview/399c401370438be4...  0ancVQ9wEcHVd0RrGICTE4
# 4  https://p.scdn.co/mp3-preview/e7eb60e9466bc3a2...  01QoK9DA7VTeTSE3MNzp4I
#
#                                                 tags genre  year  duration_ms  \
# 0  rock, alternative, indie, alternative_rock, in...   NaN  2004       222200
# ...

# %%
unique_tags = set(tag for tag_list in music_df['tags'] for tag in str(tag_list).split(','))
total_unique_tags = len(unique_tags)

print(f'There are {total_unique_tags} unique tags in the dataset.')
# Out:
# There are 200 unique tags in the dataset.

# %% [markdown]
# ## Tags and Genre simplyfing
#
# Our main recommendation system is collaborative-based recommendation and in this data tags and genre information is not stored in organized manner. Tags can be turned into binary features however dimentionality will increase by 200, potentially confusing the model and decreasing the accuracy. For the simplicity of the project, since our main focus is collaborative-based, we will drop tags and genres from content-based recommender music-dataset. However in an industrial application it is required to clean filter and organize tags for increased accuracy.

# %%
df=music_df.drop(['tags','genre'],axis=1).copy()
df
# Out:
#                  track_id                name                 artist  \
# 0      TRIOREW128F424EAF0      Mr. Brightside            The Killers
# 1      TRRIVDJ128F429B0E8          Wonderwall                  Oasis
# 2      TROUVHL128F426C441     Come as You Are                Nirvana
# 3      TRUEIND128F93038C4         Take Me Out        Franz Ferdinand
# 4      TRLNZBD128F935E4D8               Creep              Radiohead
# ...                   ...                 ...                    ...
# 50678  TRQYCFV128F9322F50       Ryusei Rocket            アンティック-珈琲店-
# 50679  TRHQCSH128F42724B7  Colors Of The Wind                ACIDMAN
# 50680  TRZRODK128F92D68D7      The Revelation               coldrain
# 50681  TRGLMEM128F9322F63   Koi no Dependence            アンティック-珈琲店-
# 50682  TRIPFKO128F42383FE         Hide & Seek  9mm Parabellum Bullet
#
#                                      spotify_preview_url  \
# 0      https://p.scdn.co/mp3-preview/4d26180e6961fd46...
# ...

# %%
# Also dropping non training related columns
df.drop(['track_id','name','artist','spotify_preview_url','spotify_id'],axis=1,inplace=True)

# %%
df
# Out:
#        year  duration_ms  danceability  energy  key  loudness  mode  \
# 0      2004       222200         0.355   0.918    1    -4.360     1
# 1      2006       258613         0.409   0.892    2    -4.373     1
# 2      1991       218920         0.508   0.826    4    -5.783     0
# 3      2004       237026         0.279   0.664    9    -8.851     1
# 4      2008       238640         0.515   0.430    7    -9.935     1
# ...     ...          ...           ...     ...  ...       ...   ...
# 50678  2008       273440         0.438   0.933    6    -3.062     0
# 50679  2004       275133         0.351   0.693    0    -6.811     1
# 50680  2014       254826         0.434   0.975   10    -3.092     0
# 50681  2008       243293         0.513   0.902    4    -3.914     0
# 50682  2008       131960         0.190   0.953    8    -4.144     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 0           0.0746      0.001190          0.000000    0.0971    0.240
# ...

# %% [markdown]
# ### Memory Problem

# %%
# Compute the cosine similarity matrix
similarity = cosine_similarity(df)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[57], line 2
#       1 # Compute the cosine similarity matrix
# ----> 2 similarity = cosine_similarity(df)
#
# File c:\Users\metin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
# ...

# %%
np.zeros((df.shape[0], df.shape[0]))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 np.zeros((df.shape[0], df.shape[0]))
#
# MemoryError: Unable to allocate 19.1 GiB for an array with shape (50683, 50683) and data type float64

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Function to compute cosine similarity in batches
def batch_cosine_similarity(df, batch_size):
    # Placeholder for cosine similarity matrix
    cosine_sim_matrix = np.zeros((df.shape[0], df.shape[0]))
    
    # for start_index in range(0, df.shape[0], batch_size):
    #     end_index = min(start_index + batch_size, df.shape[0])
    #     batch = df[start_index:end_index]
        
    #     # Compute similarity for the current batch
    #     sim = cosine_similarity(batch, df)
        
    #     # Store the results in the cosine similarity matrix
    #     cosine_sim_matrix[start_index:end_index] = sim

    return cosine_sim_matrix

# Example usage
batch_size = 10 # Adjust this based on your available memory
similarity_matrix = batch_cosine_similarity(df, batch_size)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[63], line 23
#      21 # Example usage
#      22 batch_size = 10 # Adjust this based on your available memory
# ---> 23 similarity_matrix = batch_cosine_similarity(df, batch_size)
#
# Cell In[63], line 7, in batch_cosine_similarity(df, batch_size)
#       5 def batch_cosine_similarity(df, batch_size):
#       6     # Placeholder for cosine similarity matrix
# ----> 7     cosine_sim_matrix = np.zeros((df.shape[0], df.shape[0]))
#       9     # for start_index in range(0, df.shape[0], batch_size):
#      10     #     end_index = min(start_index + batch_size, df.shape[0])
#      11     #     batch = df[start_index:end_index]
#    (...)
#      16     #     # Store the results in the cosine similarity matrix
#      17     #     cosine_sim_matrix[start_index:end_index] = sim
#      19     return cosine_sim_matrix
#
# ...
