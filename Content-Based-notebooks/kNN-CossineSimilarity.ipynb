# %%
#Import all the required packages
import pandas as pd

# Load the movies.csv file into a Pandas dataframe
music_df = pd.read_csv('../data/music_info.csv')

unique_tags = set(tag for tag_list in music_df['tags'] for tag in str(tag_list).split(','))
total_unique_tags = len(unique_tags)

print(f'There are {total_unique_tags} unique tags in the dataset.')

df=music_df.drop(['tags','genre'],axis=1).copy()
df.drop(['track_id','name','artist','spotify_preview_url','spotify_id'],axis=1,inplace=True)
music_df.head(5)
# Out:
# There are 200 unique tags in the dataset.
#              track_id             name           artist  \
# 0  TRIOREW128F424EAF0   Mr. Brightside      The Killers
# 1  TRRIVDJ128F429B0E8       Wonderwall            Oasis
# 2  TROUVHL128F426C441  Come as You Are          Nirvana
# 3  TRUEIND128F93038C4      Take Me Out  Franz Ferdinand
# 4  TRLNZBD128F935E4D8            Creep        Radiohead
#
#                                  spotify_preview_url              spotify_id  \
# 0  https://p.scdn.co/mp3-preview/4d26180e6961fd46...  09ZQ5TmUG8TSL56n0knqrj
# 1  https://p.scdn.co/mp3-preview/d012e536916c927b...  06UfBBDISthj1ZJAtX4xjj
# 2  https://p.scdn.co/mp3-preview/a1c11bb1cb231031...  0keNu0t0tqsWtExGM3nT1D
# 3  https://p.scdn.co/mp3-preview/399c401370438be4...  0ancVQ9wEcHVd0RrGICTE4
# 4  https://p.scdn.co/mp3-preview/e7eb60e9466bc3a2...  01QoK9DA7VTeTSE3MNzp4I
#
#                                                 tags genre  year  duration_ms  \
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import NearestNeighbors

# Example function to fit and query the k-NN model
def knn_recommendation(df, n_neighbors=10):
    # Initialize the k-NN model
    knn = NearestNeighbors(n_neighbors=n_neighbors, algorithm='auto', metric='cosine')
    
    # Fit the model on the data
    knn.fit(df)
    
    # Find the k-neighbors for each item in the dataset
    distances, indices = knn.kneighbors(df)
    
    return distances, indices

# Example usage
# Assuming 'df' is your DataFrame with features
n_neighbors = 10  # Number of neighbors to consider
distances, indices = knn_recommendation(df, n_neighbors)

# Example of how to use the results for recommendations
def get_recommendations(item_index, indices, n_recommendations=5):
    # Get the indices of the recommended items
    recommended_indices = indices[item_index, 1:n_recommendations+1]  # Exclude the first item since it's the query item itself
    
    return recommended_indices

# Get recommendations for a specific item
item_index = 0  # Change this to the index of the item you want recommendations for
recommendations = get_recommendations(item_index, indices)
print(f"Recommendations for item {item_index}: {recommendations}")
# Out:
# Recommendations for item 0: [10234 25287 25219  5338 29424]

# %%
# Find the index of the movie with the given title
idx = music_df[music_df['track_id'] == 'TRIOREW128F424EAF0'].index[0]
idx
# Out:
# 0

# %%
# type(indices)
np.savetxt("kNN-distances.csv", distances, delimiter=",")
np.savetxt("kNN-indices.csv", indices, delimiter=",")

# %%
distances[3][3]=
print(distances[3])
print(np.sort(distances[3]))
# Out:
# [0.00000000e+00 5.41073852e-11 1.57916569e-10 1.00000000e+02
#  1.86482274e-10 2.00179873e-10 2.03462913e-10 2.31852537e-10
#  2.88170932e-10 3.22044946e-10]
# [0.00000000e+00 5.41073852e-11 1.57916569e-10 1.86482274e-10
#  2.00179873e-10 2.03462913e-10 2.31852537e-10 2.88170932e-10
#  3.22044946e-10 1.00000000e+02]
